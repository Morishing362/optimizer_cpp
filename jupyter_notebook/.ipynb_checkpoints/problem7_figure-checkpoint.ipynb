# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import autograd.numpy as np

from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LogNorm
from matplotlib import animation
from IPython.display import HTML

from autograd import elementwise_grad, value_and_grad
from scipy.optimize import minimize
from collections import defaultdict
from itertools import zip_longest
from functools import partial

# %%
f  = lambda x, y: 0.5 * (x - y * (2 - y * (5 - y)) - 13)**2 + 0.5 * (x - y * (14 - y * (1 + y)) - 29)**2

# %%
xmin, xmax, xstep = 0, 20, 0.2
ymin, ymax, ystep = -3, 1, 0.2

# %%
x, y = np.meshgrid(np.arange(xmin, xmax + xstep, xstep), np.arange(ymin, ymax + ystep, ystep))

# %%
z = f(x, y)

# %%
minima = np.array([11.4128, -0.896805])
f(*minima)
# Out:
# 24.492126839933604

# %%
minima_ = minima.reshape(-1, 1)
minima_
# Out:
# array([[ 11.4128  ],
#        [ -0.896805]])

# %%
f(*minima_)
# Out:
# array([ 24.49212684])

# %%
fig = plt.figure(figsize=(10, 6))
ax = plt.axes(projection='3d', elev=50, azim=-50)

ax.plot_surface(x, y, z, norm=LogNorm(), rstride=1, cstride=1, 
                edgecolor='none', alpha=.8, cmap=plt.cm.jet)
ax.plot(*minima_, f(*minima_), 'r*', markersize=10)

ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_zlabel('$z$')

ax.set_xlim((xmin, xmax))
ax.set_ylim((ymin, ymax))

plt.show()

# %%
dz_dx = elementwise_grad(f, argnum=0)(x, y)
dz_dy = elementwise_grad(f, argnum=1)(x, y)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.contour(x, y, z, levels=np.logspace(0, 5, 35), norm=LogNorm(), cmap=plt.cm.jet)
ax.quiver(x, y, x - dz_dx, y - dz_dy, alpha=.5)
ax.plot(*minima_, 'r*', markersize=18)

ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

ax.set_xlim((xmin, xmax))
ax.set_ylim((ymin, ymax))

plt.show()

# %%
x0 = np.array([3., 4.])

# %% [markdown]
# **Newton**

# %%
path_Newton = np.array(
[

]
)

# %% [markdown]
# **Gauss-Newton**

# %%
path_GaussNewton = np.array(
[
[0.5, -2],
[10.1429, -1.14286],
[39.2536, 0.964871],
[21.3106, -1.12284],
[41.9407, 1.1643],
[23.7672, -1.28148],
[27.8885, 0.12505],
[12.0904, -1.23544],
[30.7275, 0.334048],
[14.6112, -1.1214],
[42.1515, 1.17996],
[23.9813, -1.29929],
[26.9426, 0.0555925],
[11.1451, -1.28666],
[27.6055, 0.104264],
[11.8146, -1.25],
[29.7598, 0.262734],
[13.7939, -1.15406],
[37.9222, 0.866146],
[20.2201, -1.08112],
[49.3116, 1.71226],
[36.6252, -3.00393],
[-2.47153, -1.94217],
[10.9941, -1.08492],
[48.5102, 1.65264],
[34.2101, -2.61836],
[2.16522, -1.66183],
[15.8008, -0.750331],
[-34.8639, -4.6035],
[-23.0032, -3.02012],
[-2.66618, -1.95361],
[10.8232, -1.09659],
[46.2346, 1.48339],
[29.3113, -1.89927],
[11.6485, -1.04009],
[60.5752, 2.55116],
[-21.5092, 8.48978],
[-27.7236, 6.17049],
[-4.33764, 4.8087],
[3.37243, 4.17214],
[4.9121, 4.01038],
[4.99966, 4.00004],
[5, 4],
[5, 4]
]
).T

# %% [markdown]
# **LMsimple**

# %%
path_LMsimple = np.array(
[
[0.5, -2],
[4.31253, -1.33906],
[17.0792, -0.540196],
[17.0792, -0.540196],
[17.0792, -0.540196],
[14.5491, -0.764277],
[14.5491, -0.764277],
[13.598, -0.765155],
[13.598, -0.765155],
[12.6749, -0.837347],
[12.6749, -0.837347],
[12.2591, -0.848602],
[12.2591, -0.848602],
[11.9242, -0.871069],
[11.9242, -0.871069],
[11.7455, -0.878555],
[11.7455, -0.878555],
[11.6191, -0.886095],
[11.6191, -0.886095],
[11.545, -0.88969],
[11.545, -0.88969],
[11.4957, -0.892442],
[11.4957, -0.892442],
[11.4656, -0.893987],
[11.4656, -0.893987],
[11.4461, -0.895044],
[11.4461, -0.895044],
[11.4339, -0.895681],
[11.4339, -0.895681],
[11.4261, -0.896097],
[11.4261, -0.896097],
[11.4212, -0.896356],
[11.4212, -0.896356],
[11.4181, -0.896521],
[11.4181, -0.896521],
[11.4162, -0.896625],
[11.4162, -0.896625],
[11.4149, -0.896691],
[11.4149, -0.896691],
[11.4141, -0.896733],
[11.4141, -0.896733],
[11.4136, -0.89676],
[11.4136, -0.89676],
[11.4133, -0.896776],
[11.4133, -0.896776],
[11.4131, -0.896787],
[11.4131, -0.896787],
[11.413, -0.896794],
[11.413, -0.896794],
[11.4129, -0.896798],
[11.4129, -0.896798],
[11.4129, -0.896801],
[11.4129, -0.896801],
[11.4128, -0.896802],
[11.4128, -0.896802],
[11.4128, -0.896803],
[11.4128, -0.896803],
[11.4128, -0.896804],
[11.4128, -0.896804],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805]
]
).T
path_LMsimple.shape
# Out:
# (2, 91)

# %% [markdown]
# **st24**

# %%
path_st24 = np.array(
[
[0.496372, -1.73328],
[0.503528, -1.52653],
[0.54049, -1.4571],
[0.650174, -1.45127],
[0.971275, -1.43555],
[1.87035, -1.39087],
[4.11196, -1.27615],
[8.50267, -1.03382],
[10.2063, -0.95303],
[12.3042, -0.818626],
[12.3042, -0.818626],
[11.5622, -0.907536],
[11.6621, -0.875591],
[11.4608, -0.898803],
[11.4793, -0.891337],
[11.4275, -0.897121],
[11.4304, -0.895413],
[11.4172, -0.896835],
[11.4174, -0.89645],
[11.4141, -0.8968],
[11.414, -0.896714],
[11.4132, -0.896801],
[11.4131, -0.896782],
[11.4131, -0.896782],
[11.4128, -0.896812],
[11.4129, -0.896797],
[11.4128, -0.896809],
[11.4128, -0.896802],
[11.4128, -0.896807],
[11.4128, -0.896804],
[11.4128, -0.896806],
[11.4128, -0.896805],
[11.4128, -0.896806],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805]
]
).T
path_st24.shape
# Out:
# (2, 64)

# %% [markdown]
# **st25**

# %%
path_st25 = np.array(
[
[0.496372, -1.73328],
[0.501069, -1.54103],
[0.520304, -1.46761],
[0.556072, -1.45603],
[0.66251, -1.45082],
[0.974464, -1.43548],
[1.8495, -1.392],
[4.04112, -1.27991],
[7.57212, -1.0893],
[9.97715, -0.959105],
[10.9227, -0.917761],
[11.4193, -0.89108],
[11.281, -0.908161],
[11.418, -0.893543],
[11.3808, -0.900037],
[11.4176, -0.895622],
[11.4047, -0.89771],
[11.4145, -0.896446],
[11.4107, -0.89705],
[11.4133, -0.896706],
[11.4123, -0.896869],
[11.4129, -0.896779],
[11.4126, -0.896822],
[11.4128, -0.896799],
[11.4127, -0.896809],
[11.4128, -0.896804],
[11.4128, -0.896806],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805],
[11.4128, -0.896805]
]
).T
path_st25.shape
# Out:
# (2, 41)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.contour(x, y, z, levels=np.logspace(0, 5, 35), norm=LogNorm(), cmap=plt.cm.jet)
ax.plot(*minima_, 'r*', markersize=18)

line, = ax.plot([], [], 'b', label='Newton-CG', lw=2)
point, = ax.plot([], [], 'bo')

ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

ax.set_xlim((xmin, xmax))
ax.set_ylim((ymin, ymax))

ax.legend(loc='upper left')

# %%
class TrajectoryAnimation(animation.FuncAnimation):
    
    def __init__(self, *paths, labels=[], fig=None, ax=None, frames=None, 
                 interval=400, repeat_delay=5, blit=True, **kwargs):

        if fig is None:
            if ax is None:
                fig, ax = plt.subplots()
            else:
                fig = ax.get_figure()
        else:
            if ax is None:
                ax = fig.gca()

        self.fig = fig
        self.ax = ax
        
        self.paths = paths

        if frames is None:
            frames = max(path.shape[1] for path in paths)
  
        self.lines = [ax.plot([], [], label=label, lw=2)[0] 
                      for _, label in zip_longest(paths, labels)]
        self.points = [ax.plot([], [], 'o', color=line.get_color())[0] 
                       for line in self.lines]

        super(TrajectoryAnimation, self).__init__(fig, self.animate, init_func=self.init_anim,
                                                  frames=frames, interval=interval, blit=blit,
                                                  repeat_delay=repeat_delay, **kwargs)

    def init_anim(self):
        for line, point in zip(self.lines, self.points):
            line.set_data([], [])
            point.set_data([], [])
        return self.lines + self.points

    def animate(self, i):
        for line, point, path in zip(self.lines, self.points, self.paths):
            line.set_data(*path[::,:i])
            point.set_data(*path[::,i-1:i])
        return self.lines + self.points

# %%
methods = [
    "Gauss-Newton",
    "LM simple",
    "LM st1",
    "LM st2"
]

# %%
paths = [path_GaussNewton, path_LMsimple, path_st24, path_st25]

# %%
zpaths = [f(*path) for path in paths]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-c9d26934cc02> in <module>()
# ----> 1 zpaths = [f(*path) for path in paths]
#
# <ipython-input-143-c9d26934cc02> in <listcomp>(.0)
# ----> 1 zpaths = [f(*path) for path in paths]
#
# TypeError: <lambda>() takes 2 positional arguments but 44 were given

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.contour(x, y, z, levels=np.logspace(0, 5, 35), norm=LogNorm(), cmap=plt.cm.jet)
ax.plot(*minima_, 'r*', markersize=10)

ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

ax.set_xlim((xmin, xmax))
ax.set_ylim((ymin, ymax))

anim = TrajectoryAnimation(*paths, labels=methods, ax=ax)

ax.legend(loc='upper left')

# %%
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-f885f4acf935> in <module>()
# ----> 1 HTML(anim.to_html5_video())
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1351                                 bitrate=rcParams['animation.bitrate'],
#    1352                                 fps=1000. / self._interval)
# -> 1353                 self.save(f.name, writer=writer)
#    1354
#    1355             # Now open and base64 encode
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1197                     for anim, d in zip(all_anim, data):
#    1198                         # TODO: See if turning off blit is really necessary
# ...
